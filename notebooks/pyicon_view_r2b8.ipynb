# %% [markdown]
# # Welcome to pyicon
#
# Example Juptyer Notebook for using pyicon

# %% [markdown]
# Load the necessary modules:

# %%
# if this line is not separated from the line below this cell has to be executed twice
# %matplotlib notebook 
#%matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pyicon as pyic  
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
import numpy as np

# %%
from matplotlib.patches import Rectangle
def add_sonett(ax):
    rectprop = dict(facecolor='none', edgecolor='k', lw=2)
    ax.add_patch(Rectangle((-12,-37.5), 5, 4, **rectprop))
    ax.text(-9.5, -33.5, 'SONETT II', ha='center', va='bottom', fontsize=8)

    rectprop = dict(facecolor='none', edgecolor='k', lw=2)
    ax.add_patch(Rectangle((1,-35), 9, 5, **rectprop))
    ax.text(5.5, -30., 'SONETT I', ha='center', va='bottom', fontsize=8)

    ax.text(-2.5, -35, 'Walvis Ridge', va='center', ha='center', rotation=45, fontsize=8)
    return

# %% [markdown]
# ## Plotting on a regular grid

# %% [markdown]
# Define a dataset with giving the path to the data and information about the triangular grid and the regular grid. The regular grid needs to be created in advance (use pyic.calc_ckdtree for that).

# %%
# run = 'exp.ocean_ncep6h_r2b8_20096-FZA'
run = 'exp.ocean_omip_long_tke_r2b8_20134-WWG'
runname = ''
gname = 'r2b8_oce_r0004'
lev = 'L128'

path_data     = f'/work/mh0033/m211054/projects/icon/icon-oes-1.3.01/experiments/{run}/outdata/'
# path_data     = f'/mnt/lustre01/work/mh0033/m300602/proj_vmix/icon/{runname}/icon-oes/experiments/{run}/'
path_grid     = f'/mnt/lustre01/work/mh0033/m300602/icon/grids/{gname}/'
path_ckdtree  = f'{path_grid}ckdtree/'
fpath_ckdtree = f'{path_grid}ckdtree/rectgrids/{gname}_res1.00_180W-180E_90S-90N.npz'
fpath_ckdtree_zave = fpath_ckdtree
fpath_fx      = f'{path_grid}{gname}_{lev}_fx.nc'

# %%
IcD = pyic.IconData(
               fname        = run+'_????????????????.nc',
               path_data    = path_data,
               path_grid    = path_grid,
               gname        = gname,
               lev          = lev,
               do_triangulation = False,
               omit_last_file   = True,
               calc_coeff       = False,
               verbose          = True,
              )
# Out:
# -v-: set paths and fnames
# -v-: set global variables
# -v-: find  ckdtrees etc.
# -v-: load tgrid
# -v-: load rgrid
# -v-: load vgrid
# -v-: list of variables and time steps

# %% [markdown]
# Start the ncview-like plotting:

# %%
PyicV = pyic.view.hplot(IcD, logplot=False, lon_reg=[-20,30], lat_reg=[-45,-20])
add_sonett(PyicV.ax)
# Out:
# <img src="data:image/png;base64,..." width="787.0500000000001">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('zos', 'to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot'…
# HBox(children=(Dropdown(description='rgrid:', options=('global_0.3', 'global_1.0', 'global_0.1'), value='globa…
# Output()

# %%
PyicV = pyic.view.vplot(IcD, log2vax=False, logplot=False)
# Out:
# <img src="data:image/png;base64,..." width="787.25">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot', 'mass…
# HBox(children=(Dropdown(description='section:', options=('170W_200pts', '30W_300pts', '30W_200pts', '170W_300p…
# Output()

# %%
#J.show_parameter()

# %%
#J.update_fig(var=J.var, step_snap=J.step_snap, sec_name=J.sec_name)

# %%
IcD.depthc
# Out:
# masked_array(data=[   6. ,   17. ,   27. ,   37. ,   47. ,   57. ,   67. ,
#                      77. ,   87. ,   97. ,  107.5,  119. ,  131.5,  145. ,
#                     159.5,  175. ,  191.5,  209. ,  228. ,  249. ,  272. ,
#                     297. ,  324. ,  353. ,  384. ,  417.5,  454. ,  493.5,
#                     536.5,  583.5,  634.5,  690. ,  750. ,  814. ,  882.5,
#                     955.5, 1033. , 1115.5, 1203.5, 1297.5, 1398. , 1505.5,
#                    1620. , 1741.5, 1870. , 2005. , 2146.5, 2295. , 2451. ,
#                    2614.5, 2785.5, 2964. , 3149. , 3340.5, 3538.5, 3743. ,
#                    3953.5, 4169.5, 4391. , 4618. , 4850.5, 5088.5, 5334. ,
#                    5589. ],
#              mask=False,
#        fill_value=1e+20)
