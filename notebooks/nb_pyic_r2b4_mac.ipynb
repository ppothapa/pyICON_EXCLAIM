# %% [markdown]
# # Welcome to pyicon
#
# Example Juptyer Notebook for using pyicon

# %% [markdown]
# Load the necessary modules:

# %%
# if this line is not separated from the line below this cell has to be executed twice
# %matplotlib notebook 
#%matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pyicon_jupyter as jup
import pyicon as pyic  
from importlib import reload
reload(pyic)
reload(jup)
# Out:
# <module 'pyicon_jupyter' from '/home/mpim/m300602/pyicon/pyicon_jupyter.py'>

# %% [markdown]
# ## Plotting on a regular grid

# %% [markdown]
# Define a dataset with giving the path to the data and information about the triangular grid and the regular grid. The regular grid needs to be created in advance (use pyic.calc_ckdtree for that).

# %%
run = 'nib0004'
runname = 'icon_08'
gname = 'r2b6'
lev = 'L64'

path_data     = f'/mnt/lustre01/work/mh0033/m300602/proj_vmix/icon/{runname}/icon-oes/experiments/{run}/'
path_grid     = f'/mnt/lustre01/work/mh0033/m300602/icon/grids/{gname}/'
path_ckdtree  = f'{path_grid}ckdtree/'
fpath_ckdtree = f'{path_grid}ckdtree/rectgrids/{gname}_res1.00_180W-180E_90S-90N.npz'
fpath_ckdtree_zave = fpath_ckdtree
fpath_fx      = f'{path_grid}{gname}_{lev}_fx.nc'

# %%
IcD = pyic.IconData(
               fname        = run+'_????????????????.nc',
               path_data    = path_data,
               path_grid    = path_grid,
               gname        = gname,
               lev          = lev,
               do_triangulation = False,
               omit_last_file   = False
              )

# %% [markdown]
# Start the ncview-like plotting:

# %%
J = jup.hplot(IcD, use_tgrid=False, logplot=False)
# Out:
# Loading zos from /mnt/lustre01/work/mh0033/m300602/proj_vmix/icon/icon_08/icon-oes/experiments/nib0004/nib0004_20010101T000000Z.nc
# <img src="data:image/png;base64,..." width="872.25">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('zos', 'to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot'…
# HBox(children=(Dropdown(description='rgrid:', options=('global_0.1', 'global_0.3', 'global_0.05', 'global_1.0'…
# Output(outputs=({'output_type': 'stream', 'text': 'Loading zos from /mnt/lustre01/work/mh0033/m300602/proj_vmi…

# %%
J = jup.vplot(IcD, log2vax=False, logplot=False)
# Out:
# Loading to from /mnt/lustre01/work/mh0033/m300602/proj_vmix/icon/icon_08/icon-oes/experiments/nib0004/nib0004_20010101T000000Z.nc
# <img src="data:image/png;base64,..." width="872.25">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot', 'mass…
# HBox(children=(Dropdown(description='section:', options=('30W_300pts', '30W_300pts', '30W_100pts', '170W_100pt…
# Output(outputs=({'output_type': 'stream', 'text': 'Loading to from /mnt/lustre01/work/mh0033/m300602/proj_vmix…

# %%
#J.show_parameter()

# %%
#J.update_fig(var=J.var, step_snap=J.step_snap, sec_name=J.sec_name)
