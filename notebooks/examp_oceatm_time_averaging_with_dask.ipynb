# %% [markdown]
# # Example on how to use time averaging with dask

# %%
# Jupyter Notebook with widget matplotlib plots
# %matplotlib notebook
# Jupyter Lab with widget matplotlib plots
# %matplotlib widget 
# with Jupyter and Jupyter Lab but without widget matplotlib plots
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%time
import sys
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset, num2date
import pyicon as pyic
import cartopy.crs as ccrs
import glob, os
import xarray as xr
import pandas as pd
import cartopy
# import seawater as sw
import datetime

import multiprocessing
from dask_jobqueue import SLURMCluster # Setting up distributed memories via slurm
from dask.utils import format_bytes
from dask.distributed import Client, LocalCluster, progress # Libaray to orchestrate distributed resources

from tempfile import NamedTemporaryFile, TemporaryDirectory # Creating temporary Files/Dirs
from getpass import getuser # Libaray to copy things
from pathlib import Path # Object oriented libary to deal with paths
# Out:
# -----calc
# sys glob os
# numpy
# netcdf
# Done modules calc.
# -----calc_xr
# sys glob os
# numpy
# netcdf
# xarray
# Done modules calc.
# -----tb
# sys
# json
# numpy
# scipy
# netcdf datetime
# matplotlib
# mybreak
# pnadas
# xarray
# done xarray
# -----IconData
# -----plotting
# -----view
# -----calc
# -----calc_xr
# -----tb
# -----IconData
# -----plotting
# -----view
# -----quickplots
# -----quickplots
# CPU times: user 1.95 s, sys: 1.72 s, total: 3.66 s
# Wall time: 32.4 s

# %% [markdown]
# ## Simulation details

# %%
run = 'exp.ocean_ncep6h_r2b8_hel20160-NCP'
path_data = f'/mnt/lustre01/work/mh0033/m211054/projects/icon/icon-oes-1.3.01/experiments/{run}/outdata/'

# %%
tave_int = ['2015-01-02', '2016-01-01']

# %%
path_scratch = f'/scratch/m/m300602/dask_tmp/{run}/'

# %%
res = 'res0.30'
fpath_ckdtree = f'/home/mpim/m300602/work/icon/grids/r2b9_oce_r0004/ckdtree/rectgrids/r2b9_oce_r0004_{res}_180W-180E_90S-90N.nc'
fpath_fx = '/pool/data/ICON/oes/input/r0004/OceanOnly_IcosSymmetric_4932m_rotatedZ37d_modified_srtm30_1min/ZSTAR/R2B9L128_fx.nc'
fpath_tgrid = f'/mnt/lustre01/work/mh0033/m300602/icon/grids/r2b9_oce_r0004/r2b9_oce_r0004_tgrid.nc'

# %%
mfdset_kwargs = dict(combine='nested', concat_dim='time', 
                     data_vars='minimal', coords='minimal', compat='override', join='override',
                     parallel=True,
                    )

# %% [markdown]
# ## Start cluster

# %%
# !echo $HOSTNAME
# Out:
# mlogin104

# %%
# Set some user specific variables
account_name = 'bm1102' # Account that is going to be 'charged' fore the computation
queue = 'gpu' # Name of the partition we want to use
job_name = 'PostProc' # Job name that is submitted via sbatch
memory = "100GiB" # Max memory per node that is going to be used - this depends on the partition
cores = 24 # Max number of cores per task that are reserved - also partition dependend
walltime = '8:00:00' # Walltime - also partition dependent

# %%
scratch_dir = Path('/scratch') / getuser()[0] / getuser() # Define the users scratch dir
# Create a temp directory where the output of distributed cluster will be written to, after this notebook
# is closed the temp directory will be closed
dask_tmp_dir = TemporaryDirectory(dir=scratch_dir, prefix=job_name)
cluster = SLURMCluster(memory=memory,
                       cores=cores,
                       project=account_name,
                       walltime=walltime,
                       queue=queue,
                       name=job_name,
                       scheduler_options={'dashboard_address': ':8787'},
                       local_directory=dask_tmp_dir.name,
                       job_extra=[f'-J {job_name}', 
                                  f'-D {dask_tmp_dir.name}',
                                  f'--begin=now',
                                  f'--output={dask_tmp_dir.name}/LOG_cluster.%j.o',
                                  f'--output={dask_tmp_dir.name}/LOG_cluster.%j.o'
                                 ],
                       interface='ib0')
# Out:
# /work/mh0033/m300602/miniconda3/envs/pyicon_py39/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36191 instead
#   warnings.warn(

# %%
print(cluster.job_script())
# Out:
# #!/usr/bin/env bash
#
# #SBATCH -J dask-worker
# #SBATCH -p gpu
# #SBATCH -A bm1102
# #SBATCH -n 1
# #SBATCH --cpus-per-task=24
# #SBATCH --mem=100G
# #SBATCH -t 8:00:00
# #SBATCH -J PostProc
# #SBATCH -D /scratch/m/m300602/PostProcde4wgz43
# #SBATCH --begin=now
# #SBATCH --output=/scratch/m/m300602/PostProcde4wgz43/LOG_cluster.%j.o
# #SBATCH --output=/scratch/m/m300602/PostProcde4wgz43/LOG_cluster.%j.o
#
# /work/mh0033/m300602/miniconda3/envs/pyicon_py39/bin/python -m distributed.cli.dask_worker tcp://10.50.32.33:35556 --nthreads 4 --nprocs 6 --memory-limit 16.67GiB --name dummy-name --nanny --death-timeout 60 --local-directory /scratch/m/m300602/PostProcde4wgz43 --interface ib0 --protocol tcp://

# %%
cluster.scale(jobs=2)
cluster
# Out:
# Tab(children=(HTML(value='\n            <div class="jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-Ou…

# %%
! squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           33556463       gpu PostProc  m300602  R       0:01      1 mg102
#           33556464       gpu PostProc  m300602  R       0:01      1 mg102

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.50.32.33:35556' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Load data

# %%
# %%time
ds_3d = xr.open_mfdataset(f'{path_data}{run}_P1D_201[5-6]*.nc', **mfdset_kwargs, chunks=dict(time=1, depth=1, depth_2=1))
ds_3d = ds_3d.sel(time=slice(*tave_int))
# Out:
# CPU times: user 1.06 s, sys: 168 ms, total: 1.23 s
# Wall time: 29.2 s

# %%
ds_3d.time.data[0], ds_3d.time.data[-1], ds_3d.time.data.size
# Out:
# (numpy.datetime64('2015-01-02T00:00:00.000000000'),
#  numpy.datetime64('2016-01-01T00:00:00.000000000'),
#  365)

# %% [markdown]
# Correct time by shifting it by half the length of the averaging period. This facillitates finding the correct averaging boundaries. It is also necessary for averaging using the 'groupby' method.

# %%
ds_3d['time'] = ds_3d.time-np.timedelta64(12, 'h')

# %% [markdown]
# ### Check which time steps are taken by groupby method later on

# %%
txt = ''
ds = ds_3d
mgroup = ds.groupby('time.month').groups
for mm in mgroup:
    txt += f'\n month: {mm}: size: {ds.time[mgroup[mm]].size}\n'
    for el in ds.time[mgroup[mm]].data:
        txt += str(el)+'\n'
print(txt)
# Out:
#  month: 1: size: 31
# 2015-01-01T00:00:00.000000000
# 2015-01-02T00:00:00.000000000
# 2015-01-03T00:00:00.000000000
# 2015-01-04T00:00:00.000000000
# 2015-01-05T00:00:00.000000000
# 2015-01-06T00:00:00.000000000
# 2015-01-07T00:00:00.000000000
# 2015-01-08T00:00:00.000000000
# 2015-01-09T00:00:00.000000000
# 2015-01-10T00:00:00.000000000
# 2015-01-11T00:00:00.000000000
# 2015-01-12T00:00:00.000000000
# 2015-01-13T00:00:00.000000000
# 2015-01-14T00:00:00.000000000
# 2015-01-15T00:00:00.000000000
# 2015-01-16T00:00:00.000000000
# 2015-01-17T00:00:00.000000000
# 2015-01-18T00:00:00.000000000
# 2015-01-19T00:00:00.000000000
# 2015-01-20T00:00:00.000000000
# 2015-01-21T00:00:00.000000000
# 2015-01-22T00:00:00.000000000
# 2015-01-23T00:00:00.000000000
# 2015-01-24T00:00:00.000000000
# 2015-01-25T00:00:00.000000000
# 2015-01-26T00:00:00.000000000
# 2015-01-27T00:00:00.000000000
# 2015-01-28T00:00:00.000000000
# 2015-01-29T00:00:00.000000000
# 2015-01-30T00:00:00.000000000
# 2015-01-31T00:00:00.000000000
#
#  month: 2: size: 28
# 2015-02-01T00:00:00.000000000
# 2015-02-02T00:00:00.000000000
# 2015-02-03T00:00:00.000000000
# 2015-02-04T00:00:00.000000000
# 2015-02-05T00:00:00.000000000
# 2015-02-06T00:00:00.000000000
# 2015-02-07T00:00:00.000000000
# 2015-02-08T00:00:00.000000000
# 2015-02-09T00:00:00.000000000
# 2015-02-10T00:00:00.000000000
# 2015-02-11T00:00:00.000000000
# 2015-02-12T00:00:00.000000000
# 2015-02-13T00:00:00.000000000
# 2015-02-14T00:00:00.000000000
# 2015-02-15T00:00:00.000000000
# 2015-02-16T00:00:00.000000000
# 2015-02-17T00:00:00.000000000
# 2015-02-18T00:00:00.000000000
# 2015-02-19T00:00:00.000000000
# 2015-02-20T00:00:00.000000000
# 2015-02-21T00:00:00.000000000
# 2015-02-22T00:00:00.000000000
# 2015-02-23T00:00:00.000000000
# 2015-02-24T00:00:00.000000000
# 2015-02-25T00:00:00.000000000
# 2015-02-26T00:00:00.000000000
# 2015-02-27T00:00:00.000000000
# 2015-02-28T00:00:00.000000000
#
#  month: 3: size: 31
# 2015-03-01T00:00:00.000000000
# 2015-03-02T00:00:00.000000000
# 2015-03-03T00:00:00.000000000
# 2015-03-04T00:00:00.000000000
# 2015-03-05T00:00:00.000000000
# 2015-03-06T00:00:00.000000000
# 2015-03-07T00:00:00.000000000
# 2015-03-08T00:00:00.000000000
# 2015-03-09T00:00:00.000000000
# 2015-03-10T00:00:00.000000000
# 2015-03-11T00:00:00.000000000
# 2015-03-12T00:00:00.000000000
# 2015-03-13T00:00:00.000000000
# 2015-03-14T00:00:00.000000000
# 2015-03-15T00:00:00.000000000
# 2015-03-16T00:00:00.000000000
# 2015-03-17T00:00:00.000000000
# 2015-03-18T00:00:00.000000000
# 2015-03-19T00:00:00.000000000
# 2015-03-20T00:00:00.000000000
# 2015-03-21T00:00:00.000000000
# 2015-03-22T00:00:00.000000000
# 2015-03-23T00:00:00.000000000
# 2015-03-24T00:00:00.000000000
# 2015-03-25T00:00:00.000000000
# 2015-03-26T00:00:00.000000000
# 2015-03-27T00:00:00.000000000
# 2015-03-28T00:00:00.000000000
# 2015-03-29T00:00:00.000000000
# 2015-03-30T00:00:00.000000000
# 2015-03-31T00:00:00.000000000
#
#  month: 4: size: 30
# 2015-04-01T00:00:00.000000000
# 2015-04-02T00:00:00.000000000
# 2015-04-03T00:00:00.000000000
# 2015-04-04T00:00:00.000000000
# 2015-04-05T00:00:00.000000000
# 2015-04-06T00:00:00.000000000
# 2015-04-07T00:00:00.000000000
# 2015-04-08T00:00:00.000000000
# 2015-04-09T00:00:00.000000000
# 2015-04-10T00:00:00.000000000
# 2015-04-11T00:00:00.000000000
# 2015-04-12T00:00:00.000000000
# 2015-04-13T00:00:00.000000000
# 2015-04-14T00:00:00.000000000
# 2015-04-15T00:00:00.000000000
# 2015-04-16T00:00:00.000000000
# 2015-04-17T00:00:00.000000000
# 2015-04-18T00:00:00.000000000
# 2015-04-19T00:00:00.000000000
# 2015-04-20T00:00:00.000000000
# 2015-04-21T00:00:00.000000000
# 2015-04-22T00:00:00.000000000
# 2015-04-23T00:00:00.000000000
# 2015-04-24T00:00:00.000000000
# 2015-04-25T00:00:00.000000000
# 2015-04-26T00:00:00.000000000
# 2015-04-27T00:00:00.000000000
# 2015-04-28T00:00:00.000000000
# 2015-04-29T00:00:00.000000000
# 2015-04-30T00:00:00.000000000
#
#  month: 5: size: 31
# 2015-05-01T00:00:00.000000000
# 2015-05-02T00:00:00.000000000
# 2015-05-03T00:00:00.000000000
# 2015-05-04T00:00:00.000000000
# 2015-05-05T00:00:00.000000000
# 2015-05-06T00:00:00.000000000
# 2015-05-07T00:00:00.000000000
# 2015-05-08T00:00:00.000000000
# 2015-05-09T00:00:00.000000000
# 2015-05-10T00:00:00.000000000
# 2015-05-11T00:00:00.000000000
# 2015-05-12T00:00:00.000000000
# 2015-05-13T00:00:00.000000000
# 2015-05-14T00:00:00.000000000
# 2015-05-15T00:00:00.000000000
# 2015-05-16T00:00:00.000000000
# 2015-05-17T00:00:00.000000000
# 2015-05-18T00:00:00.000000000
# 2015-05-19T00:00:00.000000000
# 2015-05-20T00:00:00.000000000
# 2015-05-21T00:00:00.000000000
# 2015-05-22T00:00:00.000000000
# 2015-05-23T00:00:00.000000000
# 2015-05-24T00:00:00.000000000
# 2015-05-25T00:00:00.000000000
# 2015-05-26T00:00:00.000000000
# 2015-05-27T00:00:00.000000000
# 2015-05-28T00:00:00.000000000
# 2015-05-29T00:00:00.000000000
# 2015-05-30T00:00:00.000000000
# 2015-05-31T00:00:00.000000000
#
#  month: 6: size: 30
# 2015-06-01T00:00:00.000000000
# 2015-06-02T00:00:00.000000000
# 2015-06-03T00:00:00.000000000
# 2015-06-04T00:00:00.000000000
# 2015-06-05T00:00:00.000000000
# 2015-06-06T00:00:00.000000000
# 2015-06-07T00:00:00.000000000
# 2015-06-08T00:00:00.000000000
# 2015-06-09T00:00:00.000000000
# 2015-06-10T00:00:00.000000000
# 2015-06-11T00:00:00.000000000
# 2015-06-12T00:00:00.000000000
# 2015-06-13T00:00:00.000000000
# 2015-06-14T00:00:00.000000000
# 2015-06-15T00:00:00.000000000
# 2015-06-16T00:00:00.000000000
# 2015-06-17T00:00:00.000000000
# 2015-06-18T00:00:00.000000000
# 2015-06-19T00:00:00.000000000
# 2015-06-20T00:00:00.000000000
# 2015-06-21T00:00:00.000000000
# 2015-06-22T00:00:00.000000000
# 2015-06-23T00:00:00.000000000
# 2015-06-24T00:00:00.000000000
# 2015-06-25T00:00:00.000000000
# 2015-06-26T00:00:00.000000000
# 2015-06-27T00:00:00.000000000
# 2015-06-28T00:00:00.000000000
# 2015-06-29T00:00:00.000000000
# 2015-06-30T00:00:00.000000000
#
#  month: 7: size: 31
# 2015-07-01T00:00:00.000000000
# 2015-07-02T00:00:00.000000000
# 2015-07-03T00:00:00.000000000
# 2015-07-04T00:00:00.000000000
# 2015-07-05T00:00:00.000000000
# 2015-07-06T00:00:00.000000000
# 2015-07-07T00:00:00.000000000
# 2015-07-08T00:00:00.000000000
# 2015-07-09T00:00:00.000000000
# 2015-07-10T00:00:00.000000000
# 2015-07-11T00:00:00.000000000
# 2015-07-12T00:00:00.000000000
# 2015-07-13T00:00:00.000000000
# 2015-07-14T00:00:00.000000000
# 2015-07-15T00:00:00.000000000
# 2015-07-16T00:00:00.000000000
# 2015-07-17T00:00:00.000000000
# 2015-07-18T00:00:00.000000000
# 2015-07-19T00:00:00.000000000
# 2015-07-20T00:00:00.000000000
# 2015-07-21T00:00:00.000000000
# 2015-07-22T00:00:00.000000000
# 2015-07-23T00:00:00.000000000
# 2015-07-24T00:00:00.000000000
# 2015-07-25T00:00:00.000000000
# 2015-07-26T00:00:00.000000000
# 2015-07-27T00:00:00.000000000
# 2015-07-28T00:00:00.000000000
# 2015-07-29T00:00:00.000000000
# 2015-07-30T00:00:00.000000000
# 2015-07-31T00:00:00.000000000
#
#  month: 8: size: 31
# 2015-08-01T00:00:00.000000000
# 2015-08-02T00:00:00.000000000
# 2015-08-03T00:00:00.000000000
# 2015-08-04T00:00:00.000000000
# 2015-08-05T00:00:00.000000000
# 2015-08-06T00:00:00.000000000
# 2015-08-07T00:00:00.000000000
# 2015-08-08T00:00:00.000000000
# 2015-08-09T00:00:00.000000000
# 2015-08-10T00:00:00.000000000
# 2015-08-11T00:00:00.000000000
# 2015-08-12T00:00:00.000000000
# 2015-08-13T00:00:00.000000000
# 2015-08-14T00:00:00.000000000
# 2015-08-15T00:00:00.000000000
# 2015-08-16T00:00:00.000000000
# 2015-08-17T00:00:00.000000000
# 2015-08-18T00:00:00.000000000
# 2015-08-19T00:00:00.000000000
# 2015-08-20T00:00:00.000000000
# 2015-08-21T00:00:00.000000000
# 2015-08-22T00:00:00.000000000
# 2015-08-23T00:00:00.000000000
# 2015-08-24T00:00:00.000000000
# 2015-08-25T00:00:00.000000000
# 2015-08-26T00:00:00.000000000
# 2015-08-27T00:00:00.000000000
# 2015-08-28T00:00:00.000000000
# 2015-08-29T00:00:00.000000000
# 2015-08-30T00:00:00.000000000
# 2015-08-31T00:00:00.000000000
#
#  month: 9: size: 30
# 2015-09-01T00:00:00.000000000
# 2015-09-02T00:00:00.000000000
# 2015-09-03T00:00:00.000000000
# 2015-09-04T00:00:00.000000000
# 2015-09-05T00:00:00.000000000
# 2015-09-06T00:00:00.000000000
# 2015-09-07T00:00:00.000000000
# 2015-09-08T00:00:00.000000000
# 2015-09-09T00:00:00.000000000
# 2015-09-10T00:00:00.000000000
# 2015-09-11T00:00:00.000000000
# 2015-09-12T00:00:00.000000000
# 2015-09-13T00:00:00.000000000
# 2015-09-14T00:00:00.000000000
# 2015-09-15T00:00:00.000000000
# 2015-09-16T00:00:00.000000000
# 2015-09-17T00:00:00.000000000
# 2015-09-18T00:00:00.000000000
# 2015-09-19T00:00:00.000000000
# 2015-09-20T00:00:00.000000000
# 2015-09-21T00:00:00.000000000
# 2015-09-22T00:00:00.000000000
# 2015-09-23T00:00:00.000000000
# 2015-09-24T00:00:00.000000000
# 2015-09-25T00:00:00.000000000
# 2015-09-26T00:00:00.000000000
# 2015-09-27T00:00:00.000000000
# 2015-09-28T00:00:00.000000000
# 2015-09-29T00:00:00.000000000
# 2015-09-30T00:00:00.000000000
#
#  month: 10: size: 31
# 2015-10-01T00:00:00.000000000
# 2015-10-02T00:00:00.000000000
# 2015-10-03T00:00:00.000000000
# 2015-10-04T00:00:00.000000000
# 2015-10-05T00:00:00.000000000
# 2015-10-06T00:00:00.000000000
# 2015-10-07T00:00:00.000000000
# 2015-10-08T00:00:00.000000000
# 2015-10-09T00:00:00.000000000
# 2015-10-10T00:00:00.000000000
# 2015-10-11T00:00:00.000000000
# 2015-10-12T00:00:00.000000000
# 2015-10-13T00:00:00.000000000
# 2015-10-14T00:00:00.000000000
# 2015-10-15T00:00:00.000000000
# 2015-10-16T00:00:00.000000000
# 2015-10-17T00:00:00.000000000
# 2015-10-18T00:00:00.000000000
# 2015-10-19T00:00:00.000000000
# 2015-10-20T00:00:00.000000000
# 2015-10-21T00:00:00.000000000
# 2015-10-22T00:00:00.000000000
# 2015-10-23T00:00:00.000000000
# 2015-10-24T00:00:00.000000000
# 2015-10-25T00:00:00.000000000
# 2015-10-26T00:00:00.000000000
# 2015-10-27T00:00:00.000000000
# 2015-10-28T00:00:00.000000000
# 2015-10-29T00:00:00.000000000
# 2015-10-30T00:00:00.000000000
# 2015-10-31T00:00:00.000000000
#
#  month: 11: size: 30
# 2015-11-01T00:00:00.000000000
# 2015-11-02T00:00:00.000000000
# 2015-11-03T00:00:00.000000000
# 2015-11-04T00:00:00.000000000
# 2015-11-05T00:00:00.000000000
# 2015-11-06T00:00:00.000000000
# 2015-11-07T00:00:00.000000000
# 2015-11-08T00:00:00.000000000
# 2015-11-09T00:00:00.000000000
# 2015-11-10T00:00:00.000000000
# 2015-11-11T00:00:00.000000000
# 2015-11-12T00:00:00.000000000
# 2015-11-13T00:00:00.000000000
# 2015-11-14T00:00:00.000000000
# 2015-11-15T00:00:00.000000000
# 2015-11-16T00:00:00.000000000
# 2015-11-17T00:00:00.000000000
# 2015-11-18T00:00:00.000000000
# 2015-11-19T00:00:00.000000000
# 2015-11-20T00:00:00.000000000
# 2015-11-21T00:00:00.000000000
# 2015-11-22T00:00:00.000000000
# 2015-11-23T00:00:00.000000000
# 2015-11-24T00:00:00.000000000
# 2015-11-25T00:00:00.000000000
# 2015-11-26T00:00:00.000000000
# 2015-11-27T00:00:00.000000000
# 2015-11-28T00:00:00.000000000
# 2015-11-29T00:00:00.000000000
# 2015-11-30T00:00:00.000000000
#
#  month: 12: size: 31
# 2015-12-01T00:00:00.000000000
# 2015-12-02T00:00:00.000000000
# 2015-12-03T00:00:00.000000000
# 2015-12-04T00:00:00.000000000
# 2015-12-05T00:00:00.000000000
# 2015-12-06T00:00:00.000000000
# 2015-12-07T00:00:00.000000000
# 2015-12-08T00:00:00.000000000
# 2015-12-09T00:00:00.000000000
# 2015-12-10T00:00:00.000000000
# 2015-12-11T00:00:00.000000000
# 2015-12-12T00:00:00.000000000
# 2015-12-13T00:00:00.000000000
# 2015-12-14T00:00:00.000000000
# 2015-12-15T00:00:00.000000000
# 2015-12-16T00:00:00.000000000
# 2015-12-17T00:00:00.000000000
# 2015-12-18T00:00:00.000000000
# 2015-12-19T00:00:00.000000000
# 2015-12-20T00:00:00.000000000
# 2015-12-21T00:00:00.000000000
# 2015-12-22T00:00:00.000000000
# 2015-12-23T00:00:00.000000000
# 2015-12-24T00:00:00.000000000
# 2015-12-25T00:00:00.000000000
# 2015-12-26T00:00:00.000000000
# 2015-12-27T00:00:00.000000000
# 2015-12-28T00:00:00.000000000
# 2015-12-29T00:00:00.000000000
# 2015-12-30T00:00:00.000000000
# 2015-12-31T00:00:00.000000000

# %% [markdown]
# ## Time averaging

# %% [markdown]
# In the following, different averaging methods are considered where the data set is splitted in different ways before averaging. Depending on the size of the data one or the other method might be beneficial.

# %% [markdown]
# ### Average month by month and split variables

# %%
# %%time 
# 
# fpatho = '/scratch/m/m300602/tmp/test_pp_dymwin_time_ave-Copy1.nc'
# tslice = slice(0,2)   # for trials
# dslice = slice(0,20)  # for trials
tslice = slice(None, None)
dslice = slice(None,None)
# vars_ave = ['kin']
vars_ave = ['to', 'kin', 'vort', 'zos']

print('select vars')
# ds = xr.Dataset()
ds = ds_3d[vars_ave]
print('sel')
ds = ds.isel(time=tslice, depth=dslice)

print('groupby')
mgroup = ds.groupby('time.month').groups

print('Time ave')
for mm in mgroup:
    for var in vars_ave:
        print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        ds_tave = ds[var].isel(time=mgroup[mm]).mean(dim='time')
        fpath = f'{path_scratch}/examp_time_averaging_with_dask_{var}_{mm:02d}.nc'
        print(f'Saving file {fpath}')
        ds_tave.to_netcdf(fpath)

print('All done!')
# Out:
# select vars
# sel
# groupby
# Time ave
# 2021-12-01 10:24:15
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_01.nc
# 2021-12-01 10:24:19
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_01.nc
# 2021-12-01 10:24:22
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_01.nc
# 2021-12-01 10:24:25
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_01.nc
# 2021-12-01 10:24:27
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_02.nc
# 2021-12-01 10:24:31
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_02.nc
# 2021-12-01 10:24:35
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_02.nc
# 2021-12-01 10:24:37
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_02.nc
# 2021-12-01 10:24:39
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_03.nc
# 2021-12-01 10:24:43
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_03.nc
# 2021-12-01 10:24:46
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_03.nc
# 2021-12-01 10:24:48
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_03.nc
# 2021-12-01 10:24:50
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_04.nc
# 2021-12-01 10:24:53
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_04.nc
# 2021-12-01 10:24:57
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_04.nc
# 2021-12-01 10:24:59
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_04.nc
# 2021-12-01 10:25:01
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_05.nc
# 2021-12-01 10:25:05
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_05.nc
# 2021-12-01 10:25:08
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_05.nc
# 2021-12-01 10:25:10
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_05.nc
# 2021-12-01 10:25:12
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_06.nc
# 2021-12-01 10:25:16
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_06.nc
# 2021-12-01 10:25:19
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_06.nc
# 2021-12-01 10:25:21
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_06.nc
# 2021-12-01 10:25:23
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_07.nc
# 2021-12-01 10:25:27
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_07.nc
# 2021-12-01 10:25:31
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_07.nc
# 2021-12-01 10:25:33
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_07.nc
# 2021-12-01 10:25:35
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_08.nc
# 2021-12-01 10:25:38
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_08.nc
# 2021-12-01 10:25:42
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_08.nc
# 2021-12-01 10:25:44
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_08.nc
# 2021-12-01 10:25:46
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_09.nc
# 2021-12-01 10:25:49
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_09.nc
# 2021-12-01 10:25:53
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_09.nc
# 2021-12-01 10:25:55
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_09.nc
# 2021-12-01 10:25:57
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_10.nc
# 2021-12-01 10:26:01
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_10.nc
# 2021-12-01 10:26:05
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_10.nc
# 2021-12-01 10:26:08
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_10.nc
# 2021-12-01 10:26:10
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_11.nc
# 2021-12-01 10:26:13
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_11.nc
# 2021-12-01 10:26:17
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_11.nc
# 2021-12-01 10:26:19
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_11.nc
# 2021-12-01 10:26:20
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to_12.nc
# 2021-12-01 10:26:25
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin_12.nc
# 2021-12-01 10:26:28
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort_12.nc
# 2021-12-01 10:26:31
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_zos_12.nc
# All done!
# CPU times: user 52.8 s, sys: 4.52 s, total: 57.3 s
# Wall time: 2min 17s

# %% [markdown]
# ### Average one whole year but split by variable

# %%
# %%time
vars_ave = ['to', 'kin', 'vort']
# vars_ave = ['kin']
for var in vars_ave:
    print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    ds_tave = ds_3d[var].mean(dim='time')
    fpath = f'{path_scratch}/examp_time_averaging_with_dask_{var}.nc'
    print(f'Saving file {fpath}')
    ds_tave.to_netcdf(fpath)
# Out:
# 2021-12-01 10:26:43
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_to.nc
# 2021-12-01 10:27:00
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_kin.nc
# 2021-12-01 10:27:17
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask_vort.nc
# CPU times: user 25.7 s, sys: 1.82 s, total: 27.5 s
# Wall time: 42.8 s

# %% [markdown]
# ### Average one whole year for all variables

# %%
# %%time
print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
ds_tave = ds_3d.mean(dim='time')
fpath = f'{path_scratch}/examp_time_averaging_with_dask.nc'
print(f'Saving file {fpath}')
ds_tave.to_netcdf(fpath)
# Out:
# 2021-12-01 10:27:31
# Saving file /scratch/m/m300602/dask_tmp/exp.ocean_ncep6h_r2b8_hel20160-NCP//examp_time_averaging_with_dask.nc
# CPU times: user 25.2 s, sys: 1.73 s, total: 26.9 s
# Wall time: 40.1 s
