# %%
# Jupyter Notebook with widget matplotlib plots
#%matplotlib notebook
# Jupyter Lab with widget matplotlib plots
#%matplotlib widget 
# with Jupyter and Jupyter Lab but without widget matplotlib plots
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import sys
import cartopy
import pyicon as pyic
import matplotlib

# %%
ccrs_proj = cartopy.crs.PlateCarree()

# %%
x = np.linspace(-180,180,360.)
y = np.linspace(-90,90,180.)
X, Y = np.meshgrid(x,y)
Z = np.cos(X*np.pi/180.)*np.sin(Y*np.pi/180.)

# %%
hca, hcb = pyic.arrange_axes(2,2, asp=0.5, plot_cb=[0,1,0,1],
                       sharex=True, sharey=True,
                       projection=ccrs_proj,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  #ax.set_title('axes %d'%(nn))
  #ax.set_title('vert. int. temp. bias')
  #ax.set_title('IDEMIX %d'%(nn), loc='right', fontsize=10)
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(3,3, asp=0.5, plot_cb=[0,0,1,0,0,1,0,0,1],
                       sharex=True, sharey=True,
                       projection=ccrs_proj,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  #ax.set_title('axes %d'%(nn))
  #ax.set_title('vert. int. temp. bias')
  #ax.set_title('IDEMIX %d'%(nn), loc='right', fontsize=10)
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(3,3, asp=0.5, plot_cb=True,
                       sharex=False, sharey=False,
                       xlabel='longitude', ylabel='latitude',
                       projection=ccrs_proj,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  #ax.set_title('axes %d'%(nn))
  #ax.set_title('vert. int. temp. bias')
  #ax.set_title('IDEMIX %d'%(nn), loc='right', fontsize=10)
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(4,2, asp=0.5, plot_cb=[0,0,0,1,0,0,0,1],
                       sharex=True, sharey=True,
                       projection=ccrs_proj,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  #ax.set_title('axes %d'%(nn))
  #ax.set_title('vert. int. temp. bias')
  #ax.set_title('IDEMIX %d'%(nn), loc='right', fontsize=10)
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(1,1, asp=0.5, plot_cb='bottom',
                       sharex=True, sharey=True,
                       #xlabel=xlabel, ylabel=ylabel,
                       projection=ccrs_proj,
                       fig_size_fac=3.,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('axes %d'%(nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(2,1, asp=0.5, plot_cb=True,
                       sharex=False, sharey=False,
                       xlabel='longitude', ylabel='latitude',
                       projection=ccrs_proj,
                       fig_size_fac=1.
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

hca, hcb = pyic.arrange_axes(2,1, asp=0.5, plot_cb=True,
                       sharex=False, sharey=False,
                       xlabel='longitude', ylabel='latitude',
                       projection=ccrs_proj,
                       fig_size_fac=1.5,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

hca, hcb = pyic.arrange_axes(2,1, asp=0.5, plot_cb=True,
                       sharex=False, sharey=False,
                       xlabel='longitude', ylabel='latitude',
                       projection=ccrs_proj,
                       fig_size_fac=2,
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  if cax!=0:
    cax.set_title('$^o$C')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(2,2, asp=0.5, plot_cb='right',
                       f_hcb=1.5, dcbl=0.0, #dfigr=0.1,
                       sharex=True, sharey=True,
                       projection=ccrs_proj,
                       fig_size_fac=1.
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  if cax!=0:
    cax.set_title('$^o$C')
    cax.set_ylabel('temperature bias [$^o$C]')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')

# %%
hca, hcb = pyic.arrange_axes(2,2, asp=0.5, plot_cb='bottom',
                       f_hcb=1.5, f_dcbl=0.2, dfigr=0.1,
                       sharex=True, sharey=True,
                       projection=ccrs_proj,
                       fig_size_fac=1.
                       )
for nn, (ax,cax) in enumerate(zip(hca,hcb)):
  ax.set_title('IDEMIX %d: vert. int. temp. bias' % (nn))
  hm = pyic.shade(x,y,Z,ax=ax,cax=cax,transform=ccrs_proj)
  if cax!=0:
    #cax.set_title('$^o$C')
    cax.set_xlabel('temperature bias [$^o$C]')
  pyic.plot_settings(ax=ax, projection=ccrs_proj, template='global')
