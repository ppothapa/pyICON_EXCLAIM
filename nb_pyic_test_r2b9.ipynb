# %% [markdown]
# # Welcome to pyicon
#
# Example Juptyer Notebook for using pyicon

# %% [markdown]
# Load the necessary modules:

# %%
import pyicon_jupyter as jup
import pyicon as pyic      
# %matplotlib notebook

# %% [markdown]
# ## Plotting on a regular grid

# %% [markdown]
# Define a dataset with giving the path to the data and information about the triangular grid and the regular grid. The regular grid needs to be created in advance (use pyic.calc_ckdtree for that).

# %%
path_data = '/mnt/lustre01/work/mh0033/m211054/projects/icon/solver/icon-oes-solver-HB/experiments/ocean_benchmark/outdata/'
IcD = pyic.IconData(
    fpath_grid_triangular  = path_data+'ocean_benchmark_20161011T000000Z.nc',
    #region                 = 'hurricane',
    fname_rgrid            = 'r2b9ocean_r0.05_100w_30w_2n_40n.npz',
    #fname_rgrid            = 'r2b9ocean_r0.3_180w_180e_90s_90n.npz',
    path_data              = path_data,
    search_str             = 'ocean_benchmark_????????????????.nc',
       )

# %% [markdown]
# Start the ncview-like plotting:

# %%
IcD, Ip = jup.hplot(IcD)
# Out:
# Loading zos
# SEJveChjaGlsZHJlbj0oQnV0dG9uKGRlc2NyaXB0aW9uPXUnLTEnLCBzdHlsZT1CdXR0b25TdHlsZSgpLCB0b29sdGlwPXUnZGVjJyksIEludFNsaWRlcih2YWx1ZT0wLCBjb250aW51b3VzX3XigKY=
# SEJveChjaGlsZHJlbj0oQnV0dG9uKGRlc2NyaXB0aW9uPXUnLTEnLCBzdHlsZT1CdXR0b25TdHlsZSgpLCB0b29sdGlwPXUnZGVjJyksIEludFNsaWRlcih2YWx1ZT0wLCBjb250aW51b3VzX3XigKY=
# SEJveChjaGlsZHJlbj0oRHJvcGRvd24oZGVzY3JpcHRpb249dSd2YXI6Jywgb3B0aW9ucz0odSd6b3MnLCB1J3RvJywgdSdzbycsIHUndScsIHUndicsIHUnV2luZF9TcGVlZF8xMG0nLCB1J0jigKY=
# SEJveChjaGlsZHJlbj0oVGV4dCh2YWx1ZT11Jy4vdGVzdC5wZGYnLCBjb250aW51b3VzX3VwZGF0ZT1GYWxzZSwgZGVzY3JpcHRpb249dSdOYW1lOicsIHBsYWNlaG9sZGVyPXUnLi90ZXN0LnDigKY=

# %% [markdown]
# ## Plotting on the original grid

# %% [markdown]
# Similar as before: Define a dataset with giving the path to the data and information about the triangular grid.

# %%
IcD = pyic.IconData(
       fpath_grid_triangular  = path_data+'ocean_benchmark_20161011T000000Z.nc',
       region                 = 'hurricane',
       path_data              = path_data,
       search_str             = 'ocean_benchmark_*.nc',
       lon_reg                = [-80, -75],
       lat_reg                = [16, 18],
       use_tgrid              = True,
       )

# %% [markdown]
# Start the ncview-like plotting:

# %%
IcD, Ip = jup.hplot(IcD)
# Out:
# Loading zos
# <img src="data:image/png;base64,..." width="872">
# SEJveChjaGlsZHJlbj0oQnV0dG9uKGRlc2NyaXB0aW9uPXUnLTEnLCBzdHlsZT1CdXR0b25TdHlsZSgpLCB0b29sdGlwPXUnZGVjJyksIEludFNsaWRlcih2YWx1ZT0wLCBjb250aW51b3VzX3XigKY=
# SEJveChjaGlsZHJlbj0oQnV0dG9uKGRlc2NyaXB0aW9uPXUnLTEnLCBzdHlsZT1CdXR0b25TdHlsZSgpLCB0b29sdGlwPXUnZGVjJyksIEludFNsaWRlcih2YWx1ZT0wLCBjb250aW51b3VzX3XigKY=
# SEJveChjaGlsZHJlbj0oRHJvcGRvd24oZGVzY3JpcHRpb249dSd2YXI6Jywgb3B0aW9ucz0odSd6b3MnLCB1J3RvJywgdSdzbycsIHUndScsIHUndicsIHUnV2luZF9TcGVlZF8xMG0nLCB1J0jigKY=
# SEJveChjaGlsZHJlbj0oVGV4dCh2YWx1ZT11Jy4vdGVzdC5wZGYnLCBjb250aW51b3VzX3VwZGF0ZT1GYWxzZSwgZGVzY3JpcHRpb249dSdOYW1lOicsIHBsYWNlaG9sZGVyPXUnLi90ZXN0LnDigKY=
