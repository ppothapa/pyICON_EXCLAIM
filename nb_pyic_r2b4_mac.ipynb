# %% [markdown]
# # Welcome to pyicon
#
# Example Juptyer Notebook for using pyicon

# %% [markdown]
# Load the necessary modules:

# %%
# if this line is not separated from the line below this cell has to be executed twice
# %matplotlib notebook

# %%
import pyicon_jupyter as jup
import pyicon as pyic  
from importlib import reload
reload(pyic)
reload(jup)
# Out:
# <module 'pyicon_jupyter' from '/Users/nbruggemann/syn_dropbox/sync/Promotion/src/pyicon/pyicon_jupyter.py'>

# %% [markdown]
# ## Plotting on a regular grid

# %% [markdown]
# Define a dataset with giving the path to the data and information about the triangular grid and the regular grid. The regular grid needs to be created in advance (use pyic.calc_ckdtree for that).

# %%
path_data    = '/Users/nbruggemann/work/icon_playground/icon_r2b4_test_data/icon_08/icon-oes/experiments/nib0002/'
path_ckdtree = '/Users/nbruggemann/work/icon_playground/icon_ckdtree/'
#Conf         = pyic.pyicon_configure('./config_pyicon.json')
#path_ckdtree = Conf.path_ckdtree

# %%
IcD = pyic.IconData(
                   search_str   = 'nib0002_????????????????.nc',
                   #search_str   ='nib0002_idemix*',
                   path_data    = path_data,
                   path_ckdtree = path_ckdtree,
       )

# %% [markdown]
# Start the ncview-like plotting:

# %%
reload(jup)
J = jup.hplot(IcD, use_tgrid=False, logplot=False)
# Out:
# Loading zos from /Users/nbruggemann/work/icon_playground/icon_r2b4_test_data/icon_08/icon-oes/experiments/nib0002/nib0002_20020101T000000Z.nc
# <img src="data:image/png;base64,..." width="872">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('zos', 'to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot'…
# /Users/nbruggemann/miniconda2/envs/myenv_py3/lib/python3.7/site-packages/traitlets/traitlets.py:567: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   silent = bool(old_value == new_value)
# HBox(children=(Dropdown(description='rgrid:', options=('global_0.3', 'global_1.0', 'global_0.1'), value='globa…

# %%
reload(jup)
J = jup.vplot(IcD, log2vax=False, logplot=True)
# Out:
# Loading to from /Users/nbruggemann/work/icon_playground/icon_r2b4_test_data/icon_08/icon-oes/experiments/nib0002/nib0002_20020101T000000Z.nc
# <img src="data:image/png;base64,..." width="872">
# HBox(children=(Button(description='-1', style=ButtonStyle(), tooltip='dec'), IntSlider(value=0, continuous_upd…
# HBox(children=(Dropdown(description='var:', options=('to', 'so', 'w', 'wet_c', 'wet_e', 'rho', 'rhopot', 'mass…
# HBox(children=(Dropdown(description='section:', options=('170W_100pts', '30W_200pts', '30W_100pts'), value='17…

# %%
#J.show_parameter()

# %%
#J.update_fig(var=J.var, step_snap=J.step_snap, sec_name=J.sec_name)
